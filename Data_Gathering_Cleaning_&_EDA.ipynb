# %% [markdown]
# ### Summary
# In this notebook, I bring in data from postgres via AWS, clean it, and perform some EDA to prepare for modeling.
#
# Data were gathered by the reporting team at APM Reports for the podcast "In The Dark"

# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np
import pickle

# %%
params = {
    'host': #your host  ,
    'user': 'ubuntu',
    'port': 5432,
    'database' : 'jury_selection'
}

# %%
connection_string = f'postgres://ubuntu:{params["host"]}@{params["host"]}:{params["port"]}/{params["database"]}'

engine = create_engine(connection_string)

# %% [markdown]
# ### Juror Data

# %%
jurors = pd.read_sql('SELECT * FROM jurors', engine)

# %%
jurors.head()
# Out:
#    juror_id                  trial  trial_id     race   gender race_source  \
# 0     15077  1998-6316--Bobby Rice       306  Unknown  Unknown     No info
# 1     15076  1998-6316--Bobby Rice       306  Unknown  Unknown     No info
# 2     15075  1998-6316--Bobby Rice       306  Unknown  Unknown     No info
# 3     15074  1998-6316--Bobby Rice       306  Unknown  Unknown     No info
# 4     15073  1998-6316--Bobby Rice       306  Unknown  Unknown     No info
#
#        gender_source         struck_by strike_eligibility
# 0  Jury strike sheet  Juror not struck                n/a
# 1  Jury strike sheet  Juror not struck                n/a
# 2  Jury strike sheet  Juror not struck                n/a
# 3  Jury strike sheet  Juror not struck                n/a
# 4  Jury strike sheet  Juror not struck                n/a

# %%
jurors.struck_by.value_counts()
# Out:
# Juror chosen to serve on jury    3640
# Juror not struck                 3436
# Struck by the defense            2301
# Struck for cause                 2042
# Struck by the state              1852
# Struck without notation           571
# Juror excused/absent              371
# Juror chosen as alternate         370
# Unknown                           291
# Name: struck_by, dtype: int64

# %%
jurors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14874 entries, 0 to 14873
# Data columns (total 9 columns):
# juror_id              14874 non-null int64
# trial                 14874 non-null object
# trial_id              14874 non-null int64
# race                  14874 non-null object
# gender                14874 non-null object
# race_source           14874 non-null object
# gender_source         14874 non-null object
# struck_by             14874 non-null object
# strike_eligibility    14874 non-null object
# dtypes: int64(2), object(7)
# memory usage: 1.1+ MB

# %%
jurors = jurors[['juror_id', 'trial_id', 'race', 'gender', 'struck_by', 'strike_eligibility']]

# %%
jurors.race.replace(to_replace=dict(Unknown=np.nan), inplace=True)

# %%
jurors = jurors.dropna()

# %% [markdown]
# Removed over 4,700 jurors for whom there was no race information.

# %%
jurors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10122 entries, 45 to 14873
# Data columns (total 6 columns):
# juror_id              10122 non-null int64
# trial_id              10122 non-null int64
# race                  10122 non-null object
# gender                10122 non-null object
# struck_by             10122 non-null object
# strike_eligibility    10122 non-null object
# dtypes: int64(2), object(4)
# memory usage: 553.5+ KB

# %%
jurors.gender.value_counts()
# Out:
# Female     5441
# Male       4032
# Unknown     649
# Name: gender, dtype: int64

# %%
jurors.strike_eligibility.value_counts()
# Out:
# n/a                       4700
# Both State and Defense    3504
# State                     1627
# Defense                    155
# Neither                    136
# Name: strike_eligibility, dtype: int64

# %%
jurors.head()
# Out:
#     juror_id  trial_id   race  gender         struck_by strike_eligibility
# 45     15032       255  Black    Male  Struck for cause                n/a
# 46     15031       255  White  Female  Struck for cause                n/a
# 47     15030       255  White    Male  Struck for cause                n/a
# 48     15029       255  White  Female  Struck for cause                n/a
# 49     15028       255  White    Male  Struck for cause                n/a

# %%
jurors= jurors.replace({'race': {'Black': 1, 'White': 0}})

# %%
jurors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10122 entries, 45 to 14873
# Data columns (total 6 columns):
# juror_id              10122 non-null int64
# trial_id              10122 non-null int64
# race                  10122 non-null object
# gender                10122 non-null object
# struck_by             10122 non-null object
# strike_eligibility    10122 non-null object
# dtypes: int64(2), object(4)
# memory usage: 553.5+ KB

# %% [markdown]
# ### Trial Data

# %%
trials = pd.read_sql('SELECT * FROM trials', engine)

# %%
trials.head()
# Out:
#    trial_id     defendant_name cause_number  state_strikes  defense_strikes  \
# 0       306         Bobby Rice    1998-6316           True             True
# 1       305  Edwin Hart Turner    1996-3176          False             True
# 2       304     Sheila Jackson    1992-4407          False            False
# 3       303   Christopher Fair    2005-0007          False             True
# 4       302  Richard Dickerson    2006-0075          False            False
#
#     county defendent_race second_defendent_race third_defendent_race  \
# 0  Winston          Black                   n/a                  n/a
# 1  Carroll          White                   n/a                  n/a
# 2  Winston          Black                   n/a                  n/a
# 3  Choctaw          Black                   n/a                  n/a
# 4  Grenada          Black                   n/a                  n/a
#
#   fourth_defendent_race  ...  offense_code_5 offense_title_5 offense_code_6  \
# 0                   n/a  ...            None            None           None
# 1                   n/a  ...            None            None           None
# 2                   n/a  ...            None            None           None
# 3                   n/a  ...            None            None           None
# 4                   n/a  ...            None            None           None
#
#   offense_title_6 more_than_six                         verdict case_appealed  \
# 0            None         False  Guilty on at least one offense          True
# 1            None         False  Guilty on at least one offense          True
# 2            None         False  Guilty on at least one offense          True
# 3            None         False  Guilty on at least one offense          True
# 4            None         False                         Unknown          True
#
#   batson_claim_by_defense batson_claim_by_state  voir_dire_present
# 0                   False                 False               True
# 1                   False                 False               True
# 2                   False                 False               True
# 3                   False                 False               True
# 4                   False                 False              False
#
# [5 rows x 38 columns]

# %%
trials.state_strikes.value_counts()
# Out:
# False    214
# True      91
# Name: state_strikes, dtype: int64

# %%
trials.defense_strikes.value_counts()
# Out:
# True     180
# False    125
# Name: defense_strikes, dtype: int64

# %%
trials.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Data columns (total 38 columns):
# trial_id                       305 non-null int64
# defendant_name                 305 non-null object
# cause_number                   305 non-null object
# state_strikes                  305 non-null bool
# defense_strikes                305 non-null bool
# county                         305 non-null object
# defendent_race                 305 non-null object
# second_defendent_race          305 non-null object
# third_defendent_race           305 non-null object
# fourth_defendent_race          305 non-null object
# more_than_four_defendants      305 non-null bool
# judge                          305 non-null object
# prosecutor_1                   303 non-null object
# prosecutor_2                   189 non-null object
# prosecutor_3                   21 non-null object
# prosecutors_more_than_three    305 non-null bool
# def_attny_1                    304 non-null object
# def_attny_2                    38 non-null object
# def_attny_3                    7 non-null object
# def_attnys_more_than_three     305 non-null bool
# offense_code_1                 305 non-null object
# offense_title_1                305 non-null object
# offense_code_2                 124 non-null object
# offense_title_2                124 non-null object
# offense_code_3                 53 non-null object
# offense_title_3                53 non-null object
# offense_code_4                 21 non-null object
# offense_title_4                21 non-null object
# offense_code_5                 8 non-null object
# offense_title_5                9 non-null object
# offense_code_6                 3 non-null object
# offense_title_6                3 non-null object
# more_than_six                  305 non-null bool
# verdict                        305 non-null object
# case_appealed                  305 non-null bool
# batson_claim_by_defense        305 non-null bool
# batson_claim_by_state          305 non-null bool
# voir_dire_present              305 non-null bool
# dtypes: bool(10), int64(1), object(27)
# memory usage: 69.8+ KB

# %%
trials = trials[['trial_id', 'state_strikes', 'defense_strikes', 'defendent_race', 'batson_claim_by_defense',
                'batson_claim_by_state']]

# %%
trials.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Data columns (total 6 columns):
# trial_id                   305 non-null int64
# state_strikes              305 non-null bool
# defense_strikes            305 non-null bool
# defendent_race             305 non-null object
# batson_claim_by_defense    305 non-null bool
# batson_claim_by_state      305 non-null bool
# dtypes: bool(4), int64(1), object(1)
# memory usage: 6.0+ KB

# %%
trials['defendent_race'].unique()
# Out:
# array(['Black', 'White', 'Unknown', 'Latino', 'Asian'], dtype=object)

# %%
trials = trials[trials.defendent_race != 'Unknown']
trials = trials[trials.defendent_race != 'Latino']
trials = trials[trials.defendent_race != 'Asian']

# %%
trials['defendent_race'].unique()
# Out:
# array(['Black', 'White'], dtype=object)

# %%
trials_model = trials[['trial_id', 'defendent_race']]

# %%
trials.dtypes
# Out:
# trial_id                    int64
# state_strikes                bool
# defense_strikes              bool
# defendent_race             object
# batson_claim_by_defense      bool
# batson_claim_by_state        bool
# dtype: object

# %% [markdown]
# ### Voir Dire Answers

# %%
answers = pd.read_sql('SELECT * FROM voir_dire_answers', engine)

# %%
answers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3546 entries, 0 to 3545
# Data columns (total 70 columns):
# id                      3546 non-null int64
# juror_id                3546 non-null int64
# trial_id                3546 non-null int64
# no_responses            3546 non-null bool
# married                 3546 non-null object
# children                3546 non-null object
# religious               3546 non-null object
# education               3546 non-null object
# leans_state             3546 non-null bool
# leans_defense           3546 non-null bool
# leans_ambi              3546 non-null bool
# moral_hardship          3546 non-null bool
# job_hardship            3546 non-null bool
# caretaker               3546 non-null bool
# communication           3546 non-null bool
# medical                 3546 non-null bool
# employed                3546 non-null bool
# social                  3546 non-null bool
# prior_jury              3546 non-null bool
# crime_victim            3546 non-null bool
# fam_crime_victim        3546 non-null bool
# accused                 3546 non-null bool
# fam_accused             3546 non-null bool
# eyewitness              3546 non-null bool
# fam_eyewitness          3546 non-null bool
# military                3546 non-null bool
# law_enforcement         3546 non-null bool
# fam_law_enforcement     3546 non-null bool
# premature_verdict       3546 non-null bool
# premature_guilt         3546 non-null bool
# premature_innocence     3546 non-null bool
# def_race                3546 non-null bool
# vic_race                3546 non-null bool
# def_gender              3546 non-null bool
# vic_gender              3546 non-null bool
# def_social              3546 non-null bool
# vic_social              3546 non-null bool
# def_age                 3546 non-null bool
# vic_age                 3546 non-null bool
# def_sexpref             3546 non-null bool
# vic_sexpref             3546 non-null bool
# def_incarcerated        3546 non-null bool
# vic_incarcerated        3546 non-null bool
# beliefs                 3546 non-null bool
# other_biases            3546 non-null bool
# innocence               3546 non-null bool
# take_stand              3546 non-null bool
# arrest_is_guilt         3546 non-null bool
# cant_decide             3546 non-null bool
# cant_affirm             3546 non-null bool
# cant_decide_evidence    3546 non-null bool
# cant_follow             3546 non-null bool
# know_def                3546 non-null bool
# know_vic                3546 non-null bool
# know_wit                3546 non-null bool
# know_attny              3546 non-null bool
# civil_plantiff          3546 non-null bool
# civil_def               3546 non-null bool
# civil_witness           3546 non-null bool
# witness_defense         3546 non-null bool
# witness_state           3546 non-null bool
# prior_info              3546 non-null bool
# death_hesitation        3546 non-null bool
# no_death                3546 non-null bool
# no_life                 3546 non-null bool
# no_cops                 3546 non-null bool
# yes_cops                3546 non-null bool
# legally_disqualified    3546 non-null bool
# witness_ambi            3546 non-null bool
# notes                   150 non-null object
# dtypes: bool(62), int64(3), object(5)
# memory usage: 436.4+ KB

# %%
answers.head()
# Out:
#     id  juror_id  trial_id  no_responses  married children religious  \
# 0  489         0         0          True  unknown  unknown   unknown
# 1    1         1         1         False    FALSE    FALSE   unknown
# 2    2         3         1         False    FALSE    FALSE   unknown
# 3    3         4         1         False    FALSE    FALSE   unknown
# 4    4         5         1         False    FALSE    FALSE   unknown
#
#   education  leans_state  leans_defense  ...  witness_defense  witness_state  \
# 0   unknown        False          False  ...            False          False
# 1   unknown        False          False  ...            False          False
# 2   unknown        False          False  ...            False          False
# 3   unknown        False          False  ...            False          False
# 4   unknown        False          False  ...            False          False
#
#    prior_info  death_hesitation  no_death  no_life  no_cops  yes_cops  \
# 0       False             False     False    False    False     False
# 1       False             False     False    False    False     False
# 2       False             False     False    False    False     False
# 3       False             False     False    False    False     False
# 4       False             False     False    False    False     False
#
#    legally_disqualified  witness_ambi
# 0                 False         False
# 1                 False         False
# 2                 False         False
# 3                 False         False
# 4                 False         False
#
# [5 rows x 69 columns]

# %%
answers = answers.drop(columns = ['notes', 'id'])

# %% [markdown]
# ### Struck for cause

# %%
struck_for_cause = pd.read_sql("""

    SELECT * FROM jurors WHERE struck_by = 'Struck for cause'

    """, engine)

# %%
struck_for_cause.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2042 entries, 0 to 2041
# Data columns (total 9 columns):
# juror_id              2042 non-null int64
# trial                 2042 non-null object
# trial_id              2042 non-null int64
# race                  2042 non-null object
# gender                2042 non-null object
# race_source           2042 non-null object
# gender_source         2042 non-null object
# struck_by             2042 non-null object
# strike_eligibility    2042 non-null object
# dtypes: int64(2), object(7)
# memory usage: 143.7+ KB

# %%
cause = struck_for_cause.merge(answers, on = 'juror_id')

# %%
cause.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 912 entries, 0 to 911
# Data columns (total 78 columns):
# juror_id                912 non-null int64
# trial                   912 non-null object
# trial_id_x              912 non-null int64
# race                    912 non-null object
# gender                  912 non-null object
# race_source             912 non-null object
# gender_source           912 non-null object
# struck_by               912 non-null object
# strike_eligibility      912 non-null object
# id                      912 non-null int64
# trial_id_y              912 non-null int64
# no_responses            912 non-null bool
# married                 912 non-null object
# children                912 non-null object
# religious               912 non-null object
# education               912 non-null object
# leans_state             912 non-null bool
# leans_defense           912 non-null bool
# leans_ambi              912 non-null bool
# moral_hardship          912 non-null bool
# job_hardship            912 non-null bool
# caretaker               912 non-null bool
# communication           912 non-null bool
# medical                 912 non-null bool
# employed                912 non-null bool
# social                  912 non-null bool
# prior_jury              912 non-null bool
# crime_victim            912 non-null bool
# fam_crime_victim        912 non-null bool
# accused                 912 non-null bool
# fam_accused             912 non-null bool
# eyewitness              912 non-null bool
# fam_eyewitness          912 non-null bool
# military                912 non-null bool
# law_enforcement         912 non-null bool
# fam_law_enforcement     912 non-null bool
# premature_verdict       912 non-null bool
# premature_guilt         912 non-null bool
# premature_innocence     912 non-null bool
# def_race                912 non-null bool
# vic_race                912 non-null bool
# def_gender              912 non-null bool
# vic_gender              912 non-null bool
# def_social              912 non-null bool
# vic_social              912 non-null bool
# def_age                 912 non-null bool
# vic_age                 912 non-null bool
# def_sexpref             912 non-null bool
# vic_sexpref             912 non-null bool
# def_incarcerated        912 non-null bool
# vic_incarcerated        912 non-null bool
# beliefs                 912 non-null bool
# other_biases            912 non-null bool
# innocence               912 non-null bool
# take_stand              912 non-null bool
# arrest_is_guilt         912 non-null bool
# cant_decide             912 non-null bool
# cant_affirm             912 non-null bool
# cant_decide_evidence    912 non-null bool
# cant_follow             912 non-null bool
# know_def                912 non-null bool
# know_vic                912 non-null bool
# know_wit                912 non-null bool
# know_attny              912 non-null bool
# civil_plantiff          912 non-null bool
# civil_def               912 non-null bool
# civil_witness           912 non-null bool
# witness_defense         912 non-null bool
# witness_state           912 non-null bool
# prior_info              912 non-null bool
# death_hesitation        912 non-null bool
# no_death                912 non-null bool
# no_life                 912 non-null bool
# no_cops                 912 non-null bool
# yes_cops                912 non-null bool
# legally_disqualified    912 non-null bool
# witness_ambi            912 non-null bool
# notes                   50 non-null object
# dtypes: bool(62), int64(4), object(12)
# memory usage: 176.3+ KB

# %%
cause.race.value_counts()
# Out:
# Black      488
# White      409
# Unknown     15
# Name: race, dtype: int64

# %% [markdown]
# Of the 2042 jurors struck for cause, 912 have documented voir dire answers. Of them, 53.5% are Black and 44.8% are white

# %%
cause.gender.value_counts()
# Out:
# Female     536
# Male       366
# Unknown     10
# Name: gender, dtype: int64

# %% [markdown]
# ### Examine those struck by prosecution

# %%
struck_by_pros = pd.read_sql("""

    SELECT * FROM jurors WHERE struck_by = 'Struck by the state'

    """, engine)

# %%
struck_by_pros.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1852 entries, 0 to 1851
# Data columns (total 9 columns):
# juror_id              1852 non-null int64
# trial                 1852 non-null object
# trial_id              1852 non-null int64
# race                  1852 non-null object
# gender                1852 non-null object
# race_source           1852 non-null object
# gender_source         1852 non-null object
# struck_by             1852 non-null object
# strike_eligibility    1852 non-null object
# dtypes: int64(2), object(7)
# memory usage: 130.3+ KB

# %%
struck_by_pros.race.replace(to_replace=dict(Unknown=np.nan), inplace=True)

# %%
struck_by_pros.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1852 entries, 0 to 1851
# Data columns (total 9 columns):
# juror_id              1852 non-null int64
# trial                 1852 non-null object
# trial_id              1852 non-null int64
# race                  1286 non-null object
# gender                1852 non-null object
# race_source           1852 non-null object
# gender_source         1852 non-null object
# struck_by             1852 non-null object
# strike_eligibility    1852 non-null object
# dtypes: int64(2), object(7)
# memory usage: 130.3+ KB

# %%
struck_by_pros = struck_by_pros.dropna()

# %%
struck_by_pros.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1286 entries, 21 to 1851
# Data columns (total 9 columns):
# juror_id              1286 non-null int64
# trial                 1286 non-null object
# trial_id              1286 non-null int64
# race                  1286 non-null object
# gender                1286 non-null object
# race_source           1286 non-null object
# gender_source         1286 non-null object
# struck_by             1286 non-null object
# strike_eligibility    1286 non-null object
# dtypes: int64(2), object(7)
# memory usage: 100.5+ KB

# %%
struck_by_pros['race'].unique()
# Out:
# array(['White', 'Black', 'Latino'], dtype=object)

# %%
struck_by_pros = struck_by_pros[struck_by_pros.race != 'Latino']

# %%
struck_by_pros.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1285 entries, 21 to 1851
# Data columns (total 9 columns):
# juror_id              1285 non-null int64
# trial                 1285 non-null object
# trial_id              1285 non-null int64
# race                  1285 non-null object
# gender                1285 non-null object
# race_source           1285 non-null object
# gender_source         1285 non-null object
# struck_by             1285 non-null object
# strike_eligibility    1285 non-null object
# dtypes: int64(2), object(7)
# memory usage: 100.4+ KB

# %%
struck_by_pros.groupby('race').count()
# Out:
#        juror_id  trial  trial_id  gender  race_source  gender_source  \
# race
# Black       911    911       911     911          911            911
# White       374    374       374     374          374            374
#
#        struck_by  strike_eligibility
# race
# Black        911                 911
# White        374                 374

# %% [markdown]
# The prosecution's strikes were directed toward black people 71% of the time and white people 29% of the time.

# %%
struck_by_pros.groupby('gender').count()
# Out:
#          juror_id  trial  trial_id  race  race_source  gender_source  \
# gender
# Female        730    730       730   730          730            730
# Male          479    479       479   479          479            479
# Unknown        76     76        76    76           76             76
#
#          struck_by  strike_eligibility
# gender
# Female         730                 730
# Male           479                 479
# Unknown         76                  76

# %% [markdown]
# ### Struck by Defense

# %%
struck_by_def = pd.read_sql("""

    SELECT * FROM jurors WHERE struck_by = 'Struck by the defense'

    """, engine)

# %%
struck_by_def.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2301 entries, 0 to 2300
# Data columns (total 9 columns):
# juror_id              2301 non-null int64
# trial                 2301 non-null object
# trial_id              2301 non-null int64
# race                  2301 non-null object
# gender                2301 non-null object
# race_source           2301 non-null object
# gender_source         2301 non-null object
# struck_by             2301 non-null object
# strike_eligibility    2301 non-null object
# dtypes: int64(2), object(7)
# memory usage: 161.9+ KB

# %%
struck_by_def.race.replace(to_replace=dict(Unknown=np.nan), inplace=True)

# %%
struck_by_def = struck_by_def.dropna()

# %%
struck_by_def.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1467 entries, 55 to 2300
# Data columns (total 9 columns):
# juror_id              1467 non-null int64
# trial                 1467 non-null object
# trial_id              1467 non-null int64
# race                  1467 non-null object
# gender                1467 non-null object
# race_source           1467 non-null object
# gender_source         1467 non-null object
# struck_by             1467 non-null object
# strike_eligibility    1467 non-null object
# dtypes: int64(2), object(7)
# memory usage: 114.6+ KB

# %%
struck_by_def['race'].unique()
# Out:
# array([nan, 'White', 'Black', 'Asian'], dtype=object)

# %%
struck_by_def = struck_by_def[struck_by_def.race != 'Asian']

# %%
struck_by_def.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1466 entries, 55 to 2300
# Data columns (total 9 columns):
# juror_id              1466 non-null int64
# trial                 1466 non-null object
# trial_id              1466 non-null int64
# race                  1466 non-null object
# gender                1466 non-null object
# race_source           1466 non-null object
# gender_source         1466 non-null object
# struck_by             1466 non-null object
# strike_eligibility    1466 non-null object
# dtypes: int64(2), object(7)
# memory usage: 114.5+ KB

# %%
struck_by_def.groupby('race').count()
# Out:
#        juror_id  trial  trial_id  gender  race_source  gender_source  \
# race
# Black       128    128       128     128          128            128
# White      1338   1338      1338    1338         1338           1338
#
#        struck_by  strike_eligibility
# race
# Black        128                 128
# White       1338                1338

# %% [markdown]
# The defense used 91% of its peremptory strikes on white people. It's important to note that the pool of jurors they could strike was majority white (get exact #)

# %%
struck_by_def.groupby('gender').count()
# Out:
#          juror_id  trial  trial_id  race  race_source  gender_source  \
# gender
# Female        715    715       715   715          715            715
# Male          661    661       661   661          661            661
# Unknown        90     90        90    90           90             90
#
#          struck_by  strike_eligibility
# gender
# Female         715                 715
# Male           661                 661
# Unknown         90                  90

# %% [markdown]
# ### On Jury

# %%
on_jury = pd.read_sql("""

    SELECT * FROM jurors WHERE struck_by = 'Juror chosen to serve on jury' 
    OR struck_by = 'Juror chosen as alternate'

    """, engine)

# %%
on_jury.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4010 entries, 0 to 4009
# Data columns (total 9 columns):
# juror_id              4010 non-null int64
# trial                 4010 non-null object
# trial_id              4010 non-null int64
# race                  4010 non-null object
# gender                4010 non-null object
# race_source           4010 non-null object
# gender_source         4010 non-null object
# struck_by             4010 non-null object
# strike_eligibility    4010 non-null object
# dtypes: int64(2), object(7)
# memory usage: 282.0+ KB

# %%
on_jury.race.replace(to_replace=dict(Unknown=np.nan), inplace=True)

# %%
on_jury.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4010 entries, 0 to 4009
# Data columns (total 9 columns):
# juror_id              4010 non-null int64
# trial                 4010 non-null object
# trial_id              4010 non-null int64
# race                  2702 non-null object
# gender                4010 non-null object
# race_source           4010 non-null object
# gender_source         4010 non-null object
# struck_by             4010 non-null object
# strike_eligibility    4010 non-null object
# dtypes: int64(2), object(7)
# memory usage: 282.0+ KB

# %%
on_jury = on_jury.dropna()

# %%
on_jury.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2702 entries, 29 to 4009
# Data columns (total 9 columns):
# juror_id              2702 non-null int64
# trial                 2702 non-null object
# trial_id              2702 non-null int64
# race                  2702 non-null object
# gender                2702 non-null object
# race_source           2702 non-null object
# gender_source         2702 non-null object
# struck_by             2702 non-null object
# strike_eligibility    2702 non-null object
# dtypes: int64(2), object(7)
# memory usage: 211.1+ KB

# %%
on_jury['race'].unique()
# Out:
# array(['White', 'Black'], dtype=object)

# %%
on_jury.groupby('race').count()
# Out:
#        juror_id  trial  trial_id  gender  race_source  gender_source  \
# race
# Black       861    861       861     861          861            861
# White      1841   1841      1841    1841         1841           1841
#
#        struck_by  strike_eligibility
# race
# Black        861                 861
# White       1841                1841

# %% [markdown]
# The jurors that made it on the jury (or served as alternates) were 68% white

# %%
on_jury.groupby('gender').count()
# Out:
#          juror_id  trial  trial_id  race  race_source  gender_source  \
# gender
# Female       1509   1509      1509  1509         1509           1509
# Male         1002   1002      1002  1002         1002           1002
# Unknown       191    191       191   191          191            191
#
#          struck_by  strike_eligibility
# gender
# Female        1509                1509
# Male          1002                1002
# Unknown        191                 191

# %% [markdown]
# ### Aggregate data

# %%
model = jurors.merge(answers, on = 'juror_id')

# %%
model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3458 entries, 0 to 3457
# Data columns (total 73 columns):
# juror_id                3458 non-null int64
# trial_id_x              3458 non-null int64
# race                    3458 non-null object
# gender                  3458 non-null object
# struck_by               3458 non-null object
# strike_eligibility      3458 non-null object
# trial_id_y              3458 non-null int64
# no_responses            3458 non-null bool
# married                 3458 non-null object
# children                3458 non-null object
# religious               3458 non-null object
# education               3458 non-null object
# leans_state             3458 non-null bool
# leans_defense           3458 non-null bool
# leans_ambi              3458 non-null bool
# moral_hardship          3458 non-null bool
# job_hardship            3458 non-null bool
# caretaker               3458 non-null bool
# communication           3458 non-null bool
# medical                 3458 non-null bool
# employed                3458 non-null bool
# social                  3458 non-null bool
# prior_jury              3458 non-null bool
# crime_victim            3458 non-null bool
# fam_crime_victim        3458 non-null bool
# accused                 3458 non-null bool
# fam_accused             3458 non-null bool
# eyewitness              3458 non-null bool
# fam_eyewitness          3458 non-null bool
# military                3458 non-null bool
# law_enforcement         3458 non-null bool
# fam_law_enforcement     3458 non-null bool
# premature_verdict       3458 non-null bool
# premature_guilt         3458 non-null bool
# premature_innocence     3458 non-null bool
# def_race                3458 non-null bool
# vic_race                3458 non-null bool
# def_gender              3458 non-null bool
# vic_gender              3458 non-null bool
# def_social              3458 non-null bool
# vic_social              3458 non-null bool
# def_age                 3458 non-null bool
# vic_age                 3458 non-null bool
# def_sexpref             3458 non-null bool
# vic_sexpref             3458 non-null bool
# def_incarcerated        3458 non-null bool
# vic_incarcerated        3458 non-null bool
# beliefs                 3458 non-null bool
# other_biases            3458 non-null bool
# innocence               3458 non-null bool
# take_stand              3458 non-null bool
# arrest_is_guilt         3458 non-null bool
# cant_decide             3458 non-null bool
# cant_affirm             3458 non-null bool
# cant_decide_evidence    3458 non-null bool
# cant_follow             3458 non-null bool
# know_def                3458 non-null bool
# know_vic                3458 non-null bool
# know_wit                3458 non-null bool
# know_attny              3458 non-null bool
# civil_plantiff          3458 non-null bool
# civil_def               3458 non-null bool
# civil_witness           3458 non-null bool
# witness_defense         3458 non-null bool
# witness_state           3458 non-null bool
# prior_info              3458 non-null bool
# death_hesitation        3458 non-null bool
# no_death                3458 non-null bool
# no_life                 3458 non-null bool
# no_cops                 3458 non-null bool
# yes_cops                3458 non-null bool
# legally_disqualified    3458 non-null bool
# witness_ambi            3458 non-null bool
# dtypes: bool(62), int64(3), object(8)
# memory usage: 533.6+ KB

# %%
model.head()
# Out:
#    juror_id  trial_id_x   race  gender                      struck_by  \
# 0     14522          28  White  Female           Juror excused/absent
# 1     14521          28  White    Male               Struck for cause
# 2     14520          31  White    Male               Struck for cause
# 3     14519         197  White  Female  Juror chosen to serve on jury
# 4     14478         301  Black    Male               Struck for cause
#
#   strike_eligibility  trial_id_y  no_responses  married children  ...  \
# 0                n/a          28         False  unknown  unknown  ...
# 1                n/a          28         False  unknown  unknown  ...
# 2                n/a          31         False  unknown  unknown  ...
# 3            Neither         197          True  unknown  unknown  ...
# 4                n/a         301         False  unknown  unknown  ...
#
#   witness_defense witness_state  prior_info  death_hesitation  no_death  \
# 0           False         False       False             False     False
# 1           False         False       False             False     False
# 2           False         False       False             False     False
# 3           False         False       False             False     False
# 4           False         False       False             False     False
#
#    no_life  no_cops  yes_cops  legally_disqualified  witness_ambi
# 0    False    False     False                 False         False
# 1    False    False     False                 False         False
# 2    False    False     False                 False         False
# 3    False    False     False                 False         False
# 4    False    False     False                 False         False
#
# [5 rows x 73 columns]

# %%
model = model.rename(columns = {'trial_id_x': 'trial_id'})

# %%
model = model.drop(columns = ['trial_id_y'])

# %%
model = model.merge(trials_model, on = 'trial_id')

# %%
model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3353 entries, 0 to 3352
# Data columns (total 73 columns):
# juror_id                3353 non-null int64
# trial_id                3353 non-null int64
# race                    3353 non-null object
# gender                  3353 non-null object
# struck_by               3353 non-null object
# strike_eligibility      3353 non-null object
# no_responses            3353 non-null bool
# married                 3353 non-null object
# children                3353 non-null object
# religious               3353 non-null object
# education               3353 non-null object
# leans_state             3353 non-null bool
# leans_defense           3353 non-null bool
# leans_ambi              3353 non-null bool
# moral_hardship          3353 non-null bool
# job_hardship            3353 non-null bool
# caretaker               3353 non-null bool
# communication           3353 non-null bool
# medical                 3353 non-null bool
# employed                3353 non-null bool
# social                  3353 non-null bool
# prior_jury              3353 non-null bool
# crime_victim            3353 non-null bool
# fam_crime_victim        3353 non-null bool
# accused                 3353 non-null bool
# fam_accused             3353 non-null bool
# eyewitness              3353 non-null bool
# fam_eyewitness          3353 non-null bool
# military                3353 non-null bool
# law_enforcement         3353 non-null bool
# fam_law_enforcement     3353 non-null bool
# premature_verdict       3353 non-null bool
# premature_guilt         3353 non-null bool
# premature_innocence     3353 non-null bool
# def_race                3353 non-null bool
# vic_race                3353 non-null bool
# def_gender              3353 non-null bool
# vic_gender              3353 non-null bool
# def_social              3353 non-null bool
# vic_social              3353 non-null bool
# def_age                 3353 non-null bool
# vic_age                 3353 non-null bool
# def_sexpref             3353 non-null bool
# vic_sexpref             3353 non-null bool
# def_incarcerated        3353 non-null bool
# vic_incarcerated        3353 non-null bool
# beliefs                 3353 non-null bool
# other_biases            3353 non-null bool
# innocence               3353 non-null bool
# take_stand              3353 non-null bool
# arrest_is_guilt         3353 non-null bool
# cant_decide             3353 non-null bool
# cant_affirm             3353 non-null bool
# cant_decide_evidence    3353 non-null bool
# cant_follow             3353 non-null bool
# know_def                3353 non-null bool
# know_vic                3353 non-null bool
# know_wit                3353 non-null bool
# know_attny              3353 non-null bool
# civil_plantiff          3353 non-null bool
# civil_def               3353 non-null bool
# civil_witness           3353 non-null bool
# witness_defense         3353 non-null bool
# witness_state           3353 non-null bool
# prior_info              3353 non-null bool
# death_hesitation        3353 non-null bool
# no_death                3353 non-null bool
# no_life                 3353 non-null bool
# no_cops                 3353 non-null bool
# yes_cops                3353 non-null bool
# legally_disqualified    3353 non-null bool
# witness_ambi            3353 non-null bool
# defendent_race          3353 non-null object
# dtypes: bool(62), int64(2), object(9)
# memory usage: 517.4+ KB

# %%
model['struck_by_prosecution'] = (model.struck_by == 'Struck by the state').astype(int)

# %%
model['married'].unique()
# Out:
# array(['unknown', 'divorced', 'married', 'single',
#        'living unmarried with significant other', 'widowed', 'FALSE'],
#       dtype=object)

# %%
model['married'].value_counts()
# Out:
#                                          juror_id  trial_id  race  gender  \
# married
# FALSE                                          36        36    36      36
# divorced                                       15        15    15      15
# living unmarried with significant other         1         1     1       1
# married                                       168       168   168     168
# single                                          1         1     1       1
# unknown                                      3128      3128  3128    3128
# widowed                                         4         4     4       4
#
#                                          struck_by  strike_eligibility  \
# married
# FALSE                                           36                  36
# divorced                                        15                  15
# living unmarried with significant other          1                   1
# married                                        168                 168
# single                                           1                   1
# unknown                                       3128                3128
# widowed                                          4                   4
#
#                                          no_responses  children  religious  \
# married
# FALSE                                              36        36         36
# divorced                                           15        15         15
# living unmarried with significant other             1         1          1
# married                                           168       168        168
# single                                              1         1          1
# unknown                                          3128      3128       3128
# widowed                                             4         4          4
#
#                                          education  ...  prior_info  \
# married                                             ...
# FALSE                                           36  ...          36
# divorced                                        15  ...          15
# living unmarried with significant other          1  ...           1
# married                                        168  ...         168
# single                                           1  ...           1
# unknown                                       3128  ...        3128
# widowed                                          4  ...           4
#
#                                          death_hesitation  no_death  no_life  \
# married
# FALSE                                                  36        36       36
# divorced                                               15        15       15
# living unmarried with significant other                 1         1        1
# married                                               168       168      168
# single                                                  1         1        1
# unknown                                              3128      3128     3128
# widowed                                                 4         4        4
#
#                                          no_cops  yes_cops  \
# married
# FALSE                                         36        36
# divorced                                      15        15
# living unmarried with significant other        1         1
# married                                      168       168
# single                                         1         1
# unknown                                     3128      3128
# widowed                                        4         4
#
#                                          legally_disqualified  witness_ambi  \
# married
# FALSE                                                      36            36
# divorced                                                   15            15
# living unmarried with significant other                     1             1
# married                                                   168           168
# single                                                      1             1
# unknown                                                  3128          3128
# widowed                                                     4             4
#
#                                          defendent_race  struck_by_prosecution
# married
# FALSE                                                36                     36
# divorced                                             15                     15
# living unmarried with significant other               1                      1
# married                                             168                    168
# single                                                1                      1
# unknown                                            3128                   3128
# widowed                                               4                      4
#
# [7 rows x 73 columns]

# %%
model['children'].unique()
# Out:
# array(['unknown', 'yes', 'no', 'FALSE'], dtype=object)

# %%
model['children'].value_counts()
# Out:
#           juror_id  trial_id  race  gender  struck_by  strike_eligibility  \
# children
# FALSE           36        36    36      36         36                  36
# no               8         8     8       8          8                   8
# unknown       3183      3183  3183    3183       3183                3183
# yes            126       126   126     126        126                 126
#
#           no_responses  married  religious  education  ...  prior_info  \
# children                                               ...
# FALSE               36       36         36         36  ...          36
# no                   8        8          8          8  ...           8
# unknown           3183     3183       3183       3183  ...        3183
# yes                126      126        126        126  ...         126
#
#           death_hesitation  no_death  no_life  no_cops  yes_cops  \
# children
# FALSE                   36        36       36       36        36
# no                       8         8        8        8         8
# unknown               3183      3183     3183     3183      3183
# yes                    126       126      126      126       126
#
#           legally_disqualified  witness_ambi  defendent_race  \
# children
# FALSE                       36            36              36
# no                           8             8               8
# unknown                   3183          3183            3183
# yes                        126           126             126
#
#           struck_by_prosecution
# children
# FALSE                        36
# no                            8
# unknown                    3183
# yes                         126
#
# [4 rows x 73 columns]

# %%
model['religious'].unique()
# Out:
# array(['unknown', 'yes'], dtype=object)

# %%
model['religious'].value_counts()
# Out:
#            juror_id  trial_id  race  gender  struck_by  strike_eligibility  \
# religious
# unknown        3228      3228  3228    3228       3228                3228
# yes             125       125   125     125        125                 125
#
#            no_responses  married  children  education  ...  prior_info  \
# religious                                              ...
# unknown            3228     3228      3228       3228  ...        3228
# yes                 125      125       125        125  ...         125
#
#            death_hesitation  no_death  no_life  no_cops  yes_cops  \
# religious
# unknown                3228      3228     3228     3228      3228
# yes                     125       125      125      125       125
#
#            legally_disqualified  witness_ambi  defendent_race  \
# religious
# unknown                    3228          3228            3228
# yes                         125           125             125
#
#            struck_by_prosecution
# religious
# unknown                     3228
# yes                          125
#
# [2 rows x 73 columns]

# %%
model['education'].unique()
# Out:
# array(['unknown', 'attended graduate school', 'attended college',
#        'college graduate'], dtype=object)

# %%
model['education'].value_counts()
# Out:
#                           juror_id  trial_id  race  gender  struck_by  \
# education
# attended college                 7         7     7       7          7
# attended graduate school         6         6     6       6          6
# college graduate                 1         1     1       1          1
# unknown                       3339      3339  3339    3339       3339
#
#                           strike_eligibility  no_responses  married  children  \
# education
# attended college                           7             7        7         7
# attended graduate school                   6             6        6         6
# college graduate                           1             1        1         1
# unknown                                 3339          3339     3339      3339
#
#                           religious  ...  prior_info  death_hesitation  \
# education                            ...
# attended college                  7  ...           7                 7
# attended graduate school          6  ...           6                 6
# college graduate                  1  ...           1                 1
# unknown                        3339  ...        3339              3339
#
#                           no_death  no_life  no_cops  yes_cops  \
# education
# attended college                 7        7        7         7
# attended graduate school         6        6        6         6
# college graduate                 1        1        1         1
# unknown                       3339     3339     3339      3339
#
#                           legally_disqualified  witness_ambi  defendent_race  \
# education
# attended college                             7             7               7
# attended graduate school                     6             6               6
# college graduate                             1             1               1
# unknown                                   3339          3339            3339
#
#                           struck_by_prosecution
# education
# attended college                              7
# attended graduate school                      6
# college graduate                              1
# unknown                                    3339
#
# [4 rows x 73 columns]

# %%
model= model.replace({'race': {'Black': 1, 'White': 0}})

# %%
model = model.drop(columns = ['married', 'children', 'religious', 'education'])

# %%
model['strike_eligibility'].unique()
# Out:
# array(['n/a', 'Both State and Defense', 'State', 'Neither', 'Defense'],
#       dtype=object)

# %%
model = model[model.strike_eligibility != 'n/a']

model = model[model.strike_eligibility != 'Neither']

model = model[model.strike_eligibility != 'Defense']

# %%
model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2216 entries, 2 to 3352
# Data columns (total 70 columns):
# juror_id                 2216 non-null int64
# trial_id                 2216 non-null int64
# race                     2216 non-null int64
# gender                   2216 non-null object
# struck_by                2216 non-null object
# strike_eligibility       2216 non-null object
# no_responses             2216 non-null bool
# leans_state              2216 non-null bool
# leans_defense            2216 non-null bool
# leans_ambi               2216 non-null bool
# moral_hardship           2216 non-null bool
# job_hardship             2216 non-null bool
# caretaker                2216 non-null bool
# communication            2216 non-null bool
# medical                  2216 non-null bool
# employed                 2216 non-null bool
# social                   2216 non-null bool
# prior_jury               2216 non-null bool
# crime_victim             2216 non-null bool
# fam_crime_victim         2216 non-null bool
# accused                  2216 non-null bool
# fam_accused              2216 non-null bool
# eyewitness               2216 non-null bool
# fam_eyewitness           2216 non-null bool
# military                 2216 non-null bool
# law_enforcement          2216 non-null bool
# fam_law_enforcement      2216 non-null bool
# premature_verdict        2216 non-null bool
# premature_guilt          2216 non-null bool
# premature_innocence      2216 non-null bool
# def_race                 2216 non-null bool
# vic_race                 2216 non-null bool
# def_gender               2216 non-null bool
# vic_gender               2216 non-null bool
# def_social               2216 non-null bool
# vic_social               2216 non-null bool
# def_age                  2216 non-null bool
# vic_age                  2216 non-null bool
# def_sexpref              2216 non-null bool
# vic_sexpref              2216 non-null bool
# def_incarcerated         2216 non-null bool
# vic_incarcerated         2216 non-null bool
# beliefs                  2216 non-null bool
# other_biases             2216 non-null bool
# innocence                2216 non-null bool
# take_stand               2216 non-null bool
# arrest_is_guilt          2216 non-null bool
# cant_decide              2216 non-null bool
# cant_affirm              2216 non-null bool
# cant_decide_evidence     2216 non-null bool
# cant_follow              2216 non-null bool
# know_def                 2216 non-null bool
# know_vic                 2216 non-null bool
# know_wit                 2216 non-null bool
# know_attny               2216 non-null bool
# civil_plantiff           2216 non-null bool
# civil_def                2216 non-null bool
# civil_witness            2216 non-null bool
# witness_defense          2216 non-null bool
# witness_state            2216 non-null bool
# prior_info               2216 non-null bool
# death_hesitation         2216 non-null bool
# no_death                 2216 non-null bool
# no_life                  2216 non-null bool
# no_cops                  2216 non-null bool
# yes_cops                 2216 non-null bool
# legally_disqualified     2216 non-null bool
# witness_ambi             2216 non-null bool
# defendent_race           2216 non-null object
# struck_by_prosecution    2216 non-null int64
# dtypes: bool(62), int64(4), object(4)
# memory usage: 290.0+ KB

# %%
model['struck_by_prosecution'].value_counts()
# Out:
#                        juror_id  trial_id  race  gender  struck_by  \
# struck_by_prosecution
# 0                          1664      1664  1664    1664       1664
# 1                           552       552   552     552        552
#
#                        strike_eligibility  no_responses  leans_state  \
# struck_by_prosecution
# 0                                    1664          1664         1664
# 1                                     552           552          552
#
#                        leans_defense  leans_ambi  ...  witness_state  \
# struck_by_prosecution                             ...
# 0                               1664        1664  ...           1664
# 1                                552         552  ...            552
#
#                        prior_info  death_hesitation  no_death  no_life  \
# struck_by_prosecution
# 0                            1664              1664      1664     1664
# 1                             552               552       552      552
#
#                        no_cops  yes_cops  legally_disqualified  witness_ambi  \
# struck_by_prosecution
# 0                         1664      1664                  1664          1664
# 1                          552       552                   552           552
#
#                        defendent_race
# struck_by_prosecution
# 0                                1664
# 1                                 552
#
# [2 rows x 69 columns]

# %% [markdown]
# Class imbalance: 25% struck by pros, 75% move to defense

# %% [markdown]
# #### Feature Reduction

# %%
model = model.drop(columns=['juror_id', 'trial_id', 'strike_eligibility', 'struck_by' , 'no_responses'])

# %%
model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2216 entries, 2 to 3352
# Data columns (total 66 columns):
# race                     2216 non-null int64
# gender                   2216 non-null object
# leans_state              2216 non-null bool
# leans_defense            2216 non-null bool
# leans_ambi               2216 non-null bool
# moral_hardship           2216 non-null bool
# job_hardship             2216 non-null bool
# caretaker                2216 non-null bool
# communication            2216 non-null bool
# medical                  2216 non-null bool
# employed                 2216 non-null bool
# social                   2216 non-null bool
# prior_jury               2216 non-null bool
# crime_victim             2216 non-null bool
# fam_crime_victim         2216 non-null bool
# accused                  2216 non-null bool
# fam_accused              2216 non-null bool
# eyewitness               2216 non-null bool
# fam_eyewitness           2216 non-null bool
# military                 2216 non-null bool
# law_enforcement          2216 non-null bool
# fam_law_enforcement      2216 non-null bool
# premature_verdict        2216 non-null bool
# premature_guilt          2216 non-null bool
# premature_innocence      2216 non-null bool
# def_race                 2216 non-null bool
# vic_race                 2216 non-null bool
# def_gender               2216 non-null bool
# vic_gender               2216 non-null bool
# def_social               2216 non-null bool
# vic_social               2216 non-null bool
# def_age                  2216 non-null bool
# vic_age                  2216 non-null bool
# def_sexpref              2216 non-null bool
# vic_sexpref              2216 non-null bool
# def_incarcerated         2216 non-null bool
# vic_incarcerated         2216 non-null bool
# beliefs                  2216 non-null bool
# other_biases             2216 non-null bool
# innocence                2216 non-null bool
# take_stand               2216 non-null bool
# arrest_is_guilt          2216 non-null bool
# cant_decide              2216 non-null bool
# cant_affirm              2216 non-null bool
# cant_decide_evidence     2216 non-null bool
# cant_follow              2216 non-null bool
# know_def                 2216 non-null bool
# know_vic                 2216 non-null bool
# know_wit                 2216 non-null bool
# know_attny               2216 non-null bool
# civil_plantiff           2216 non-null bool
# civil_def                2216 non-null bool
# civil_witness            2216 non-null bool
# witness_defense          2216 non-null bool
# witness_state            2216 non-null bool
# prior_info               2216 non-null bool
# death_hesitation         2216 non-null bool
# no_death                 2216 non-null bool
# no_life                  2216 non-null bool
# no_cops                  2216 non-null bool
# yes_cops                 2216 non-null bool
# legally_disqualified     2216 non-null bool
# witness_ambi             2216 non-null bool
# defendent_race           2216 non-null int64
# struck_by_prosecution    2216 non-null int64
# same_race                2216 non-null int64
# dtypes: bool(61), int64(4), object(1)
# memory usage: 235.9+ KB

# %%
for column in model.columns[2:63]:
    print(model[column].value_counts())
# Out:
# False    2201
# True       15
# Name: leans_state, dtype: int64
# False    2207
# True        9
# Name: leans_defense, dtype: int64
# False    2198
# True       18
# Name: leans_ambi, dtype: int64
# False    2214
# True        2
# Name: moral_hardship, dtype: int64
# False    2204
# True       12
# Name: job_hardship, dtype: int64
# False    2212
# True        4
# Name: caretaker, dtype: int64
# False    2209
# True        7
# Name: communication, dtype: int64
# False    2203
# True       13
# Name: medical, dtype: int64
# False    2210
# True        6
# Name: employed, dtype: int64
# False    2214
# True        2
# Name: social, dtype: int64
# False    1960
# True      256
# Name: prior_jury, dtype: int64
# False    2128
# True       88
# Name: crime_victim, dtype: int64
# False    2111
# True      105
# Name: fam_crime_victim, dtype: int64
# False    2183
# True       33
# Name: accused, dtype: int64
# False    1951
# True      265
# Name: fam_accused, dtype: int64
# False    2216
# Name: eyewitness, dtype: int64
# False    2216
# Name: fam_eyewitness, dtype: int64
# False    2211
# True        5
# Name: military, dtype: int64
# False    2175
# True       41
# Name: law_enforcement, dtype: int64
# False    1782
# True      434
# Name: fam_law_enforcement, dtype: int64
# False    2216
# Name: premature_verdict, dtype: int64
# False    2216
# Name: premature_guilt, dtype: int64
# False    2215
# True        1
# Name: premature_innocence, dtype: int64
# False    2216
# Name: def_race, dtype: int64
# False    2216
# Name: vic_race, dtype: int64
# False    2216
# Name: def_gender, dtype: int64
# False    2216
# Name: vic_gender, dtype: int64
# False    2216
# Name: def_social, dtype: int64
# False    2216
# Name: vic_social, dtype: int64
# False    2216
# Name: def_age, dtype: int64
# False    2216
# Name: vic_age, dtype: int64
# False    2216
# Name: def_sexpref, dtype: int64
# False    2216
# Name: vic_sexpref, dtype: int64
# False    2216
# Name: def_incarcerated, dtype: int64
# False    2216
# Name: vic_incarcerated, dtype: int64
# False    2214
# True        2
# Name: beliefs, dtype: int64
# False    2212
# True        4
# Name: other_biases, dtype: int64
# False    2215
# True        1
# Name: innocence, dtype: int64
# False    2216
# Name: take_stand, dtype: int64
# False    2216
# Name: arrest_is_guilt, dtype: int64
# False    2216
# Name: cant_decide, dtype: int64
# False    2216
# Name: cant_affirm, dtype: int64
# False    2215
# True        1
# Name: cant_decide_evidence, dtype: int64
# False    2216
# Name: cant_follow, dtype: int64
# False    2082
# True      134
# Name: know_def, dtype: int64
# False    2035
# True      181
# Name: know_vic, dtype: int64
# False    2037
# True      179
# Name: know_wit, dtype: int64
# False    2035
# True      181
# Name: know_attny, dtype: int64
# False    2216
# Name: civil_plantiff, dtype: int64
# False    2214
# True        2
# Name: civil_def, dtype: int64
# False    2215
# True        1
# Name: civil_witness, dtype: int64
# False    2216
# Name: witness_defense, dtype: int64
# False    2208
# True        8
# Name: witness_state, dtype: int64
# False    1893
# True      323
# Name: prior_info, dtype: int64
# False    2195
# True       21
# Name: death_hesitation, dtype: int64
# False    2214
# True        2
# Name: no_death, dtype: int64
# False    2216
# Name: no_life, dtype: int64
# False    2216
# Name: no_cops, dtype: int64
# False    2214
# True        2
# Name: yes_cops, dtype: int64
# False    2216
# Name: legally_disqualified, dtype: int64
# False    2213
# True        3
# Name: witness_ambi, dtype: int64

# %% [markdown]
# remove columns with very little variability (<21 in one class)
#
# Stay: prior_jury, crime_victim, fam_crime_victim, accused, fam_accused, fam_law_enforcement, know_def, know_vic, know_wit, know_attny, prior_info, death_hesitation

# %%
model = model[['struck_by_prosecution','race', 'same_race','prior_jury', 'crime_victim', 'fam_crime_victim', 'accused', 'fam_accused', 'fam_law_enforcement', 'know_def', 
               'know_vic', 'know_wit', 'know_attny', 'prior_info', 'death_hesitation']]

# %%
model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2216 entries, 2 to 3352
# Data columns (total 15 columns):
# struck_by_prosecution    2216 non-null int64
# race                     2216 non-null int64
# same_race                2216 non-null int64
# prior_jury               2216 non-null bool
# crime_victim             2216 non-null bool
# fam_crime_victim         2216 non-null bool
# accused                  2216 non-null bool
# fam_accused              2216 non-null bool
# fam_law_enforcement      2216 non-null bool
# know_def                 2216 non-null bool
# know_vic                 2216 non-null bool
# know_wit                 2216 non-null bool
# know_attny               2216 non-null bool
# prior_info               2216 non-null bool
# death_hesitation         2216 non-null bool
# dtypes: bool(12), int64(3)
# memory usage: 95.2 KB

# %% [markdown]
# #### Add column

# %%
model['defendent_race'].unique()
# Out:
# array(['White', 'Black'], dtype=object)

# %%
model = model.replace({'defendent_race': {'Black': 1, 'White': 0}})

# %%
model['same_race'] = (model.race == model.defendent_race).astype(int)

# %%
model.head()
# Out:
#    struck_by_prosecution  race  same_race  prior_jury  crime_victim  \
# 2                      0     1          0       False         False
# 3                      0     1          0       False         False
# 4                      0     0          1       False         False
# 5                      0     1          0       False         False
# 6                      0     0          1       False         False
#
#    fam_crime_victim  accused  fam_accused  fam_law_enforcement  know_def  \
# 2             False    False        False                False     False
# 3             False    False        False                False     False
# 4             False    False        False                False     False
# 5             False    False        False                 True     False
# 6             False    False        False                False     False
#
#    know_vic  know_wit  know_attny  prior_info  death_hesitation
# 2     False     False       False       False             False
# 3     False     False       False       False             False
# 4     False     False       False       False             False
# 5     False     False       False       False             False
# 6     False     False       False       False             False

# %% [markdown]
# ## Move data to modeling notebook

# %%
with open('model.pickle' , 'wb') as to_write:
    pickle.dump(model, to_write)

# %% [markdown]
# ### Data for strike visualization

# %%
visual = jurors[['race', 'struck_by', 'strike_eligibility']]

visual.info()

visual = visual[visual.race != 'Unknown']
visual = visual[visual.race != 'Latino']
visual = visual[visual.race != 'Asian']

visual.race.unique()

with open('visual.pickle' , 'wb') as to_write:
    pickle.dump(visual, to_write)
